# %% [markdown]
# # 🧩 PuzzleRadar v3.0 — Fazenda de GPUs Gratuitas (Google Colab Tesla T4)
# ### Nó Inteligente de Mineração & Exaustão de Chaves Criptográficas (Bitcoin Puzzle #66, ETH, SOL)
#
# ---
# ### 💡 Como Usar Múltiplas Contas do Google (Fazenda de Mineração Gratuita):
# 1. Abra este notebook em quantas contas Google você desejar (Conta 1, Conta 2, Conta 3, etc.).
# 2. No menu superior, vá em **Ambiente de Execução** ➔ **Alterar tipo de ambiente de execução** ➔ Selecione **T4 GPU** (100% Gratuito).
# 3. No campo `NODE_NAME` abaixo, dê um nome exclusivo para cada conta (ex: `colab-conta-01`, `colab-conta-02`).
# 4. Execute as células. Todas as contas vão se conectar automaticamente ao seu pool no PuzzleRadar, agregando hashrate massivo!

# %%
# 🛡️ Célula 1: Anti-Desconexão Automática (Keepalive)
import IPython
from google.colab import output

display(IPython.display.Javascript('''
 function ClickConnect(){
   console.log("[PuzzleRadar Colab Farm] Mantendo conexao ativa..."); 
   document.querySelector("colab-connect-button").click();
 }
 setInterval(ClickConnect, 60000);
'''))
print("✅ Keepalive ativado! Sua sessão permanecerá conectada.")

# %%
# ⚡ Célula 2: Verificar GPU Tesla T4 Ativa
# !nvidia-smi

# %%
# 📦 Célula 3: Baixar e Instalar Dependências Rápidas
# !pip install -q requests ecdsa base58 pycryptodome
# !curl -s -O https://puzzleradar-production.up.railway.app/solver/colab_worker.py
print("✅ Dependências e script atualizados com sucesso!")

# %%
# 🚀 Célula 4: Iniciar Mineração na Fazenda Colab
# ⚠️ ALTERE O NODE_NAME PARA CADA CONTA GOOGLE (ex: colab-conta-01, colab-conta-02)
NODE_NAME = "colab-farm-node-01" #@param {type:"string"}
API_URL = "https://puzzleradar-production.up.railway.app" #@param {type:"string"}

# !python colab_worker.py --api="$API_URL" --name="$NODE_NAME"
